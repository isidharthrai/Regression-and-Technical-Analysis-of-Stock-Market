# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
from pandas.api.types import is_list_like
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
end = dt.date.today()
start = dt.datetime(end.year,end.month-1,end.day)

# %% [markdown]
# Collecting the DataSet

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532978', 'quandl', start=start, end=end )['Close'])    #Bajaj_Finserv

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM500387', 'quandl', start=start, end=end )['Close'])    #ICICI_Prudentia

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM533519', 'quandl', start=start, end=end )['Close'])    #LT_Finance

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM500490', 'quandl', start=start, end=end )['Close'])    #Bajaj_Holdings

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM532960', 'quandl', start=start, end=end )['Close'])    #Indiabulls_Vent

# %% [markdown]
# Renaming the close columns

# %%
Bajaj_Finserv = com_df1.rename(columns={'Close':'Bajaj_Finserv'})
ICICI_Prudentia = com_df2.rename(columns={'Close':'ICICI_Prudentia'})
LT_Finance = com_df3.rename(columns={'Close':'LT_Finance'})
Bajaj_Holdings = com_df4.rename(columns={'Close':'Bajaj_Holdings'})
Indiabulls_Vent = com_df5.rename(columns={'Close':'Indiabulls_Vent'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((Bajaj_Finserv.join(ICICI_Prudentia, how="outer")).join(LT_Finance, how="outer")).join(Bajaj_Holdings, how="outer")).join(Indiabulls_Vent,how="outer")

# %%
close_df
# Out:
#             Bajaj_Finserv  ICICI_Prudentia  LT_Finance  Bajaj_Holdings  \
# Date
# 2018-08-14        7073.10         17276.65      179.05         2985.25
# 2018-08-13        6949.55         17158.20      174.55         2979.80
# 2018-08-10        7086.20         17259.90      177.30         2989.80
# 2018-08-09        7070.50         17273.70      180.75         2999.50
# 2018-08-08        7050.25         17227.50      174.80         2986.10
# 2018-08-07        7006.35         17218.50      176.40         2968.75
# 2018-08-06        6913.75         17373.90      179.90         2965.25
# 2018-08-03        6931.30         17446.00      181.00         2978.60
# 2018-08-02        6908.10         17423.25      175.25         2938.75
# 2018-08-01        7003.10         17216.40      176.15         2927.20
# 2018-07-31        6985.90         17064.15      175.80         2916.40
# 2018-07-30        6888.45         17174.95      178.35         2952.95
# 2018-07-27        6919.55         17129.30      177.45         2991.90
# 2018-07-26        7028.00         17527.35      178.25         2969.50
# 2018-07-25        6956.05         17487.95      184.05         2939.55
# 2018-07-24        6826.15         17758.85      178.80         2992.40
# 2018-07-23        6937.30         16864.25      170.75         3048.70
# 2018-07-20        6666.20         16525.75      155.30         3018.80
# 2018-07-19        6306.90         16196.05      151.00         2944.50
# 2018-07-18        6364.00         16197.15      151.35         2952.20
# 2018-07-17        6352.15         16011.80      147.10         2984.60
# 2018-07-16        6248.00         16301.75      141.60         2948.00
#
#             Indiabulls_Vent
# Date
# 2018-08-14           744.65
# 2018-08-13           710.10
# 2018-08-10           712.95
# 2018-08-09           679.00
# 2018-08-08           650.65
# 2018-08-07           659.50
# 2018-08-06           639.50
# 2018-08-03           625.00
# 2018-08-02           602.00
# 2018-08-01           608.40
# 2018-07-31           596.00
# 2018-07-30           576.65
# 2018-07-27           572.95
# 2018-07-26           568.80
# 2018-07-25           548.95
# 2018-07-24           531.40
# 2018-07-23           506.10
# 2018-07-20           501.30
# 2018-07-19           496.30
# 2018-07-18           486.65
# 2018-07-17           479.35
# 2018-07-16           460.15

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets.head()
# Out:
#             Bajaj_Finserv  ICICI_Prudentia  LT_Finance  Bajaj_Holdings  \
# Date
# 2018-08-14            NaN              NaN         NaN             NaN
# 2018-08-13      -0.017468        -0.006856   -0.025133       -0.001826
# 2018-08-10       0.019663         0.005927    0.015755        0.003356
# 2018-08-09      -0.002216         0.000800    0.019459        0.003244
# 2018-08-08      -0.002864        -0.002675   -0.032918       -0.004467
#
#             Indiabulls_Vent
# Date
# 2018-08-14              NaN
# 2018-08-13        -0.046398
# 2018-08-10         0.004014
# 2018-08-09        -0.047619
# 2018-08-08        -0.041753

# %% [markdown]
# # Pair Plotting

# %%
sns.jointplot('ICICI_Prudentia','Bajaj_Finserv',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('ICICI_Prudentia','LT_Finance',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('ICICI_Prudentia','Bajaj_Holdings',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('ICICI_Prudentia','Indiabulls_Vent',rets, kind='scatter',height=5, color='orange')

# %%
sns.pairplot(rets.dropna(),height=4)

# %% [markdown]
# # Correlation Matrix

# %%
sns.heatmap(rets.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %%
sns.heatmap(close_df.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Bajaj_Finserv','LT_Finance','Bajaj_Holdings','Indiabulls_Vent']]
X = sm.add_constant(X)
y=close_df['ICICI_Prudentia']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        ICICI_Prudentia   R-squared:                       0.889
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     34.10
# Date:                Wed, 15 Aug 2018   Prob (F-statistic):           6.48e-08
# Time:                        00:38:06   Log-Likelihood:                -142.68
# No. Observations:                  22   AIC:                             295.4
# Df Residuals:                      17   BIC:                             300.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1.181e+04   3830.798      3.082      0.007    3724.413    1.99e+04
# Bajaj_Finserv      -0.0879      0.519     -0.169      0.868      -1.183       1.007
# LT_Finance         39.8039      9.495      4.192      0.001      19.770      59.838
# Bajaj_Holdings     -0.2513      1.396     -0.180      0.859      -3.197       2.694
# Indiabulls_Vent    -0.3735      0.778     -0.480      0.637      -2.016       1.269
# ==============================================================================
# Omnibus:                        3.932   Durbin-Watson:                   2.287
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                2.824
# Skew:                           0.878   Prob(JB):                        0.244
# Kurtosis:                       2.983   Cond. No.                     7.46e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(20,10))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates',size=20)
ax.set_ylabel('Closed Prices',size=20)
ax.set_title('ICICI_Prudentia Predicted Values',size=20)
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.legend(prop={'size':20})
