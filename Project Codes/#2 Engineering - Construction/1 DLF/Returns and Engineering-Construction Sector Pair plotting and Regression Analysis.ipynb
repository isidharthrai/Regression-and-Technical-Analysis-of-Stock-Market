# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
from pandas.api.types import is_list_like
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
end = dt.date.today()
start = dt.datetime(end.year,end.month-1,end.day-1)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532868', 'quandl', start=start, end=end )['Close'])   #DLF

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM533150', 'quandl', start=start, end=end )['Close'])   #Godrej_Prop

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM533273', 'quandl', start=start, end=end )['Close'])   #Oberoi_Realty

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM533274', 'quandl', start=start, end=end )['Close'])    #Prestige_Estate

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM533033', 'quandl', start=start, end=end )['Close'])    #ISGEC_Heavy_Eng

# %% [markdown]
# Renaming the close columns

# %%
DLF = com_df1.rename(columns={'Close':'DLF'})
Godrej_Prop = com_df2.rename(columns={'Close':'Godrej_Prop'})
Oberoi_Realty = com_df3.rename(columns={'Close':'Oberoi_Realty'})
Prestige_Estate = com_df4.rename(columns={'Close':'Prestige_Estate'})
ISGEC_Heavy_Eng = com_df5.rename(columns={'Close':'ISGEC_Heavy_Eng'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((DLF.join(Godrej_Prop, how="outer")).join(Oberoi_Realty, how="outer")).join(Prestige_Estate, how="outer")).join(ISGEC_Heavy_Eng,how="outer")

# %%
close_df
# Out:
#                DLF  Godrej_Prop  Oberoi_Realty  Prestige_Estate  \
# Date
# 2018-08-13  194.50       690.15         483.35           250.40
# 2018-08-10  196.60       693.80         481.95           249.95
# 2018-08-09  200.65       712.45         476.05           250.60
# 2018-08-08  189.00       718.50         479.55           250.70
# 2018-08-07  186.75       711.80         475.85           252.35
# 2018-08-06  189.25       711.35         481.60           254.20
# 2018-08-03  188.90       733.40         482.85           255.90
# 2018-08-02  188.05       724.55         481.05           256.60
# 2018-08-01  193.05       743.10         488.45           260.00
# 2018-07-31  196.15       713.55         495.80           250.80
# 2018-07-30  188.70       714.30         491.20           263.90
# 2018-07-27  190.05       687.20         480.95           268.40
# 2018-07-26  189.85       680.50         479.40           266.30
# 2018-07-25  183.70       677.75         464.05           266.55
# 2018-07-24  188.50       687.35         477.80           260.10
# 2018-07-23  177.20       657.85         482.95           256.15
# 2018-07-20  170.75       657.80         484.95           248.30
# 2018-07-19  170.10       665.80         465.60           252.65
# 2018-07-18  170.75       670.70         457.80           252.55
# 2018-07-17  179.60       691.90         463.95           254.95
# 2018-07-16  178.15       671.45         461.50           254.35
# 2018-07-13  187.85       706.60         476.70           261.65
# 2018-07-12  189.55       701.40         475.40           271.55
#
#             ISGEC_Heavy_Eng
# Date
# 2018-08-13          6177.60
# 2018-08-10          6159.45
# 2018-08-09          6016.60
# 2018-08-08          6005.50
# 2018-08-07          5800.10
# 2018-08-06          5760.90
# 2018-08-03          5742.55
# 2018-08-02          5787.15
# 2018-08-01          5673.80
# 2018-07-31          5777.45
# 2018-07-30          5740.85
# 2018-07-27          5741.95
# 2018-07-26          5616.75
# 2018-07-25          5691.20
# 2018-07-24          5530.00
# 2018-07-23          5420.70
# 2018-07-20          5490.65
# 2018-07-19          5474.60
# 2018-07-18          5595.95
# 2018-07-17          5552.95
# 2018-07-16          5501.55
# 2018-07-13          5576.80
# 2018-07-12          5556.40

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets.head()
# Out:
#                  DLF  Godrej_Prop  Oberoi_Realty  Prestige_Estate  \
# Date
# 2018-08-13       NaN          NaN            NaN              NaN
# 2018-08-10  0.010797     0.005289      -0.002896        -0.001797
# 2018-08-09  0.020600     0.026881      -0.012242         0.002601
# 2018-08-08 -0.058061     0.008492       0.007352         0.000399
# 2018-08-07 -0.011905    -0.009325      -0.007716         0.006582
#
#             ISGEC_Heavy_Eng
# Date
# 2018-08-13              NaN
# 2018-08-10        -0.002938
# 2018-08-09        -0.023192
# 2018-08-08        -0.001845
# 2018-08-07        -0.034202

# %% [markdown]
# # Pair Plotting

# %%
sns.jointplot('DLF','Godrej_Prop',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('DLF','Oberoi_Realty',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('DLF','Prestige_Estate',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('DLF','ISGEC_Heavy_Eng',rets, kind='scatter',height=5, color='orange')

# %%
sns.pairplot(rets.dropna(),height=4)
#pt.savefig("PairPlotting")

# %% [markdown]
# # Correlation Matrix

# %%
sns.heatmap(rets.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %%
sns.heatmap(close_df.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Godrej_Prop','Oberoi_Realty','Prestige_Estate','ISGEC_Heavy_Eng']]
X = sm.add_constant(X)
y=close_df['DLF']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DLF   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     19.08
# Date:                Mon, 13 Aug 2018   Prob (F-statistic):           2.79e-06
# Time:                        23:15:42   Log-Likelihood:                -61.971
# No. Observations:                  23   AIC:                             133.9
# Df Residuals:                      18   BIC:                             139.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            -230.7740     60.269     -3.829      0.001    -357.394    -104.154
# Godrej_Prop         0.0962      0.046      2.115      0.049       0.001       0.192
# Oberoi_Realty       0.2102      0.104      2.030      0.057      -0.007       0.428
# Prestige_Estate     0.4201      0.142      2.960      0.008       0.122       0.718
# ISGEC_Heavy_Eng     0.0248      0.005      4.901      0.000       0.014       0.035
# ==============================================================================
# Omnibus:                        1.122   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.571   Jarque-Bera (JB):                0.995
# Skew:                           0.456   Prob(JB):                        0.608
# Kurtosis:                       2.546   Cond. No.                     4.13e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(20,10))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates',size=20)
ax.set_ylabel('Closed Prices',size=20)
ax.set_title('DLF Predicted Values',size=20)
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.legend(prop={'size':20})
