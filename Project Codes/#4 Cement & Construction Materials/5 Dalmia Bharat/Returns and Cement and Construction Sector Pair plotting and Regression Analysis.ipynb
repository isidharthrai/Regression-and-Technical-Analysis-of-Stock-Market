# %% [markdown]
# Importing all the modules

# %%
import datetime as dt
import pandas as pd
from pandas.api.types import is_list_like
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as data
import matplotlib.pyplot as pt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# %% [markdown]
# Specifying the Date

# %%
end = dt.date.today()
start = dt.datetime(end.year,end.month-1,end.day)

# %% [markdown]
# Collecting the Data set

# %%
com_df1 = pd.DataFrame(data.DataReader('BSE/BOM532538', 'quandl', start=start, end=end )['Close'])    #UltraTechCement

# %%
com_df2 = pd.DataFrame(data.DataReader('BSE/BOM500387', 'quandl', start=start, end=end )['Close'])    #Shree_Cements

# %%
com_df3 = pd.DataFrame(data.DataReader('BSE/BOM500425', 'quandl', start=start, end=end )['Close'])    #Ambuja_Cements

# %%
com_df4 = pd.DataFrame(data.DataReader('BSE/BOM500410', 'quandl', start=start, end=end )['Close'])    #ACC

# %%
com_df5 = pd.DataFrame(data.DataReader('BSE/BOM533309', 'quandl', start=start, end=end )['Close'])    #Dalmia_Bharat

# %% [markdown]
# Renaming the close columns

# %%
UltraTechCement = com_df1.rename(columns={'Close':'UltraTechCement'})
Shree_Cements = com_df2.rename(columns={'Close':'Shree_Cements'})
Ambuja_Cements = com_df3.rename(columns={'Close':'Ambuja_Cements'})
ACC = com_df4.rename(columns={'Close':'ACC'})
Dalmia_Bharat = com_df5.rename(columns={'Close':'Dalmia_Bharat'})

# %% [markdown]
# Joinig all the data frames

# %%
close_df = (((UltraTechCement.join(Shree_Cements, how="outer")).join(Ambuja_Cements, how="outer")).join(ACC, how="outer")).join(Dalmia_Bharat,how="outer")

# %%
close_df
# Out:
#             UltraTechCement  Shree_Cements  Ambuja_Cements      ACC  \
# Date
# 2018-08-14          4296.25       17276.65          226.55  1565.15
# 2018-08-13          4199.30       17158.20          220.65  1517.55
# 2018-08-10          4243.25       17259.90          227.45  1545.30
# 2018-08-09          4301.35       17273.70          232.55  1572.10
# 2018-08-08          4240.65       17227.50          230.35  1536.15
# 2018-08-07          4209.85       17218.50          229.75  1538.40
# 2018-08-06          4177.05       17373.90          228.15  1523.05
# 2018-08-03          4175.35       17446.00          225.75  1519.35
# 2018-08-02          4177.50       17423.25          228.80  1540.60
# 2018-08-01          4193.90       17216.40          233.50  1532.80
# 2018-07-31          4189.95       17064.15          230.05  1527.15
# 2018-07-30          4235.80       17174.95          226.85  1506.00
# 2018-07-27          4124.35       17129.30          224.85  1534.05
# 2018-07-26          4139.65       17527.35          223.80  1524.65
# 2018-07-25          4049.45       17487.95          209.50  1469.15
# 2018-07-24          4136.80       17758.85          212.70  1473.25
# 2018-07-23          4007.90       16864.25          197.95  1305.35
# 2018-07-20          3884.25       16525.75          194.25  1292.40
# 2018-07-19          3860.10       16196.05          193.05  1274.45
# 2018-07-18          3852.55       16197.15          195.75  1293.20
# 2018-07-17          3901.65       16011.80          195.65  1287.85
# 2018-07-16          3866.35       16301.75          190.55  1268.90
#
#             Dalmia_Bharat
# Date
# 2018-08-14        2593.45
# 2018-08-13        2550.20
# 2018-08-10        2647.40
# 2018-08-09        2650.75
# 2018-08-08        2647.90
# 2018-08-07        2635.15
# 2018-08-06        2643.50
# 2018-08-03        2673.20
# 2018-08-02        2660.80
# 2018-08-01        2664.50
# 2018-07-31        2654.10
# 2018-07-30        2627.45
# 2018-07-27        2692.30
# 2018-07-26        2602.20
# 2018-07-25        2571.75
# 2018-07-24        2575.95
# 2018-07-23        2398.45
# 2018-07-20        2357.45
# 2018-07-19        2307.95
# 2018-07-18        2329.15
# 2018-07-17        2359.65
# 2018-07-16        2323.65

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
rets = close_df.pct_change()                                    #returns -- one day percent change for each of the stocks
rets.head()
# Out:
#             UltraTechCement  Shree_Cements  Ambuja_Cements       ACC  \
# Date
# 2018-08-14              NaN            NaN             NaN       NaN
# 2018-08-13        -0.022566      -0.006856       -0.026043 -0.030412
# 2018-08-10         0.010466       0.005927        0.030818  0.018286
# 2018-08-09         0.013692       0.000800        0.022423  0.017343
# 2018-08-08        -0.014112      -0.002675       -0.009460 -0.022868
#
#             Dalmia_Bharat
# Date
# 2018-08-14            NaN
# 2018-08-13      -0.016677
# 2018-08-10       0.038115
# 2018-08-09       0.001265
# 2018-08-08      -0.001075

# %% [markdown]
# # Pair Plotting

# %%
sns.jointplot('Dalmia_Bharat','Shree_Cements',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('Dalmia_Bharat','Ambuja_Cements',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('Dalmia_Bharat','ACC',rets, kind='scatter',height=5, color='orange')

# %%
sns.jointplot('Dalmia_Bharat','UltraTechCement',rets, kind='scatter',height=5, color='orange')

# %%
sns.pairplot(rets.dropna(),height=4)

# %% [markdown]
# # Correlation Matrix

# %%
sns.heatmap(rets.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %%
sns.heatmap(close_df.corr(),annot=True,fmt=".3g",cmap='YlGnBu')

# %% [markdown]
# <H2> Risk Return Analysis

# %%
fig, ax = pt.subplots(figsize=(8,6))
pt.scatter(rets.mean(), rets.std())
pt.xlabel('Expected returns')
pt.ylabel('Standard deviations/ Risks')
pt.title('Risk and Return Analysis')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    pt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'top',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.2),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# <h3>Steps for regression</h3>
# <li>Construct y (dependent variable series)
# <li>Construct matrix (dataframe) of X (independent variable series)
# <li>Add intercept
# <li>Model the regression
# <li>Get the results
# <h3>The statsmodels library contains various regression packages. We'll use the OLS (Ordinary Least Squares) model

# %%
import numpy as np
import statsmodels.api as sm
X=close_df[['Shree_Cements','Ambuja_Cements','ACC','UltraTechCement']]
X = sm.add_constant(X)
y=close_df['Dalmia_Bharat']
model = sm.OLS(y,X,missing='drop')             #drop rows with missing values
result = model.fit()                           #adjusts the data to model
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Dalmia_Bharat   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     126.8
# Date:                Wed, 15 Aug 2018   Prob (F-statistic):           2.04e-12
# Time:                        00:18:06   Log-Likelihood:                -100.93
# No. Observations:                  22   AIC:                             211.9
# Df Residuals:                      17   BIC:                             217.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             476.7553    437.337      1.090      0.291    -445.944    1399.455
# Shree_Cements       0.0749      0.027      2.798      0.012       0.018       0.131
# Ambuja_Cements      6.8397      1.951      3.506      0.003       2.724      10.955
# ACC                 0.3518      0.329      1.070      0.299      -0.342       1.045
# UltraTechCement    -0.2921      0.142     -2.053      0.056      -0.592       0.008
# ==============================================================================
# Omnibus:                        1.005   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.605   Jarque-Bera (JB):                0.473
# Skew:                           0.359   Prob(JB):                        0.790
# Kurtosis:                       2.990   Cond. No.                     1.34e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h3>Plotting the Predicted values and actual values to the model

# %%
fig, ax = pt.subplots(figsize=(20,10))
ax.plot(y, color="#2498B0", label="Actual values")
ax.plot(result.fittedvalues, color='#f4c20d', label="Predicted values")
ax.set_xlabel('Dates',size=20)
ax.set_ylabel('Closed Prices',size=20)
ax.set_title('Dalmia_Bharat Predicted Values',size=20)
p,q = ax.get_legend_handles_labels()
ax.legend(p, q)
pt.legend(prop={'size':20})
